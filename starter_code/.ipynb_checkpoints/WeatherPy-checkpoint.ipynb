# %% [markdown]
# ## WeatherPy Analysis

# %% [markdown]
# - From the Latitude vs Temperature plot, we can see that temperature is warmer near the equator, between -20 to 20 degrees. The hottest temperature seen at this time is close to
# -20 degrees with a temperature around 90 degrees F.
# - There is no strong correlation between latitude and humidity. There are several latitude points with 100% humidity. However, lowest humidity points are between 20 – 40 degrees and also -40 to -20 degrees.
# - City Latitude and Wind speed do not seem to have a strong relationship either. Most of the latitudes have wind speed between 0-10 mph. However, there are several outliers of wind speed between 20-33 mph in the Northern Hemisphere, especially at latitudes 40 degrees to 70 degrees.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os

# Import API key
import api_keys
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

# Review the nearest_city function in citipy

#city = citipy.nearest_city(28,-80.6)
#city.city_name

# Review the cities list
cities
# Out:
# ['saint george',
#  'tasiilaq',
#  'hilo',
#  'provideniya',
#  'tuktoyaktuk',
#  'illoqqortoormiut',
#  'punta arenas',
#  'esperance',
#  'thompson',
#  'mataura',
#  'ushuaia',
#  'verkhnyaya inta',
#  'hermanus',
#  'puerto ayora',
#  'isangel',
#  'bilma',
#  'marzuq',
#  'hualmay',
#  'port hardy',
#  'lavrentiya',
#  'samusu',
#  'taolanaro',
#  'qaanaaq',
#  'kabale',
#  'longyearbyen',
#  'albany',
#  'svetlyy',
#  'vaini',
#  'belaya gora',
#  'maniitsoq',
#  'jibuti',
#  'saint-joseph',
#  'jamestown',
#  'rikitea',
#  'udachnyy',
#  'new norfolk',
#  'rundu',
#  'gazanjyk',
#  'upernavik',
#  'sayyan',
#  'port elizabeth',
#  'lorengau',
#  'cherskiy',
#  'avarua',
#  'yar-sale',
#  'alofi',
#  'dingle',
#  'barrow',
#  'tongren',
#  'ust-nera',
#  'bathsheba',
#  'makakilo city',
#  'ribeira grande',
#  'half moon bay',
#  'touros',
#  'leh',
#  'bluff',
#  'boddam',
#  'lebu',
#  'benguela',
#  'pilot butte',
#  'emerald',
#  'kunhegyes',
#  'tomatlan',
#  'chimbote',
#  'sangar',
#  'chuy',
#  'hithadhoo',
#  'morehead',
#  'balikpapan',
#  'sandomierz',
#  'castro',
#  'viligili',
#  'namibe',
#  'mahebourg',
#  'aratoca',
#  'cidreira',
#  'kyren',
#  'nizhneyansk',
#  'bonthe',
#  'northam',
#  'santa cruz',
#  'busselton',
#  'petropavlovsk-kamchatskiy',
#  'lakatoro',
#  'hambantota',
#  'klaksvik',
#  'nikolskoye',
#  'katoro',
#  'coahuayana',
#  'yumen',
#  'yellowknife',
#  'rio grande',
#  'necochea',
#  'barcelos',
#  'cape town',
#  'palu',
#  'ust-tsilma',
#  'kurumkan',
#  'san andres',
#  'payo',
#  'pacific grove',
#  'port alfred',
#  'hamilton',
#  'mar del plata',
#  'ormara',
#  'samalaeulu',
#  'katsuura',
#  'georgetown',
#  'kaitangata',
#  'codrington',
#  'vaitupu',
#  'ixtapa',
#  'isla mujeres',
#  'chokurdakh',
#  'rivera',
#  'kavaratti',
#  'dogondoutchi',
#  'guerrero negro',
#  'lompoc',
#  'kapaa',
#  'bethel',
#  'atuona',
#  'khatanga',
#  'trelew',
#  'san vicente',
#  'dikson',
#  'tres passos',
#  'halifax',
#  'south venice',
#  'pisco',
#  'bredasdorp',
#  'bilibino',
#  'san policarpo',
#  'ponta do sol',
#  'aklavik',
#  'oussouye',
#  'butaritari',
#  'novyy urengoy',
#  'nioro',
#  'san patricio',
#  'los llanos de aridane',
#  'kabinda',
#  'koungou',
#  'kodiak',
#  'santa isabel do rio negro',
#  'bandarbeyla',
#  'hobart',
#  'ilulissat',
#  'clyde river',
#  'amderma',
#  'mvangue',
#  'formoso do araguaia',
#  'nelson bay',
#  'mahajanga',
#  'muros',
#  'uribia',
#  'wanning',
#  'luwuk',
#  'nkwerre',
#  'kungurtug',
#  'port-gentil',
#  'victoria',
#  'north adams',
#  'kidal',
#  'dolinsk',
#  'san francisco',
#  'talnakh',
#  'itarema',
#  'oshkosh',
#  'east london',
#  'ayan',
#  'balkanabat',
#  'mullaitivu',
#  'atasu',
#  'maarianhamina',
#  'saint-leu',
#  'mount gambier',
#  'kruisfontein',
#  'mys shmidta',
#  'moberly',
#  'igarka',
#  'kodinsk',
#  'berbera',
#  'luderitz',
#  'nantucket',
#  'sioux lookout',
#  'alta',
#  'vila franca do campo',
#  'cabo rojo',
#  'souillac',
#  'port blair',
#  'yanam',
#  'oranjemund',
#  'mayumba',
#  'adrar',
#  'saint-philippe',
#  'bambanglipuro',
#  'airai',
#  'ostrovnoy',
#  'zuenoula',
#  'palmer',
#  'ancud',
#  'marsh harbour',
#  'grand river south east',
#  'kahului',
#  'artyom',
#  'tonstad',
#  'caravelas',
#  'cockburn town',
#  'luang prabang',
#  'kulu',
#  'kavieng',
#  'muisne',
#  'vardo',
#  'bara',
#  'sitka',
#  'smithers',
#  'dali',
#  'cheuskiny',
#  'gazni',
#  'hami',
#  'pochutla',
#  'waingapu',
#  'inuvik',
#  'labutta',
#  'kununurra',
#  'biltine',
#  'olafsvik',
#  'smirnykh',
#  'ponta delgada',
#  'fredericton',
#  'tuatapere',
#  'san ignacio',
#  'saint-prosper',
#  'huejuquilla el alto',
#  'bambous virieux',
#  'velingara',
#  'englehart',
#  'belmonte',
#  'marsala',
#  'bargal',
#  'gualaceo',
#  'rumford',
#  'obluche',
#  'quchan',
#  'petropavlovskoye',
#  'zonguldak',
#  'faya',
#  'samarai',
#  'asau',
#  'carnarvon',
#  'road town',
#  'arica',
#  'ipora',
#  'jelling',
#  'beyneu',
#  'bengkulu',
#  'altona',
#  'bolungarvik',
#  'torbay',
#  'palauig',
#  'beloha',
#  'evensk',
#  'fairbanks',
#  'fengzhen',
#  'hays',
#  'attawapiskat',
#  'arraial do cabo',
#  'raudeberg',
#  'tiksi',
#  'saleaula',
#  'khandyga',
#  'tsihombe',
#  'fevralsk',
#  'richards bay',
#  'hasaki',
#  'angoche',
#  'iskateley',
#  'kondoa',
#  'tigil',
#  'henties bay',
#  'rawson',
#  'iquique',
#  'vanimo',
#  'bokspits',
#  'kotaparh',
#  'kangaatsiaq',
#  'saldanha',
#  'coquimbo',
#  'dakoro',
#  'dongsheng',
#  'georgiyevka',
#  'yerbogachen',
#  'mandsaur',
#  'darnah',
#  'saskylakh',
#  'kuche',
#  'moa',
#  'san cristobal',
#  'rudbar',
#  'broome',
#  'tabiauea',
#  'cabo san lucas',
#  'atar',
#  'santa maria',
#  'biala podlaska',
#  'buraydah',
#  'dalvik',
#  'tutoia',
#  'sorland',
#  'gudari',
#  'sao caetano de odivelas',
#  'horn',
#  'ketchikan',
#  'okha',
#  'meulaboh',
#  'rock sound',
#  'mirina',
#  'morros',
#  'komsomolskiy',
#  'belushya guba',
#  'karpathos',
#  'nanortalik',
#  'cap malheureux',
#  'inhambane',
#  'zhezkazgan',
#  'rio gallegos',
#  'salalah',
#  'nipawin',
#  'chernyshevskiy',
#  'leningradskiy',
#  'rantepao',
#  'nemuro',
#  'katsiveli',
#  'roald',
#  'berlevag',
#  'paamiut',
#  'pokhara',
#  'rottingdean',
#  'grand-santi',
#  'saryshagan',
#  'acapulco',
#  'khonuu',
#  'manzini',
#  'palizada',
#  'barentsburg',
#  'zhigansk',
#  'tequila',
#  'gravdal',
#  'faanui',
#  'karratha',
#  'parana',
#  'lujan',
#  'puyo',
#  'banjar',
#  'mozirje',
#  'tukums',
#  'sentyabrskiy',
#  'visby',
#  'caohai',
#  'calvinia',
#  'sakakah',
#  'lolua',
#  'mecca',
#  'wilbraham',
#  'springbok',
#  'port hedland',
#  'lagoa',
#  'buloh kasap',
#  'teguise',
#  'waddan',
#  'scottsbluff',
#  'sultanpur',
#  'laguna',
#  'comodoro rivadavia',
#  'haines junction',
#  'mayo',
#  'severo-kurilsk',
#  'rincon',
#  'chilca',
#  'bubaque',
#  'marietta',
#  'axim',
#  'betioky',
#  'norman wells',
#  'touho',
#  'felanitx',
#  'kalmunai',
#  'zyryanovsk',
#  'port macquarie',
#  'itoman',
#  'nokaneng',
#  'grants',
#  'sydney',
#  'araouane',
#  'galesong',
#  'southampton',
#  'yinchuan',
#  'mogadishu',
#  'walvis bay',
#  'lubango',
#  'bima',
#  'gurjaani',
#  'dharchula',
#  'nishihara',
#  'mizdah',
#  'selenice',
#  'jimeta',
#  'college',
#  'mount isa',
#  'tumannyy',
#  'viransehir',
#  'baykit',
#  'jiazi',
#  'krutinka',
#  'san ramon',
#  'altamont',
#  'banda aceh',
#  'fort nelson',
#  'luorong',
#  'zhangye',
#  'vestmannaeyjar',
#  'mayna',
#  'nacala',
#  'rocha',
#  'quatre cocos',
#  'yakeshi',
#  'puerto escondido',
#  'camacha',
#  'netrakona',
#  'verkhnyaya toyma',
#  'cavalcante',
#  'svetlaya',
#  'taoudenni',
#  'anadyr',
#  'xingyi',
#  'kieta',
#  'tazovskiy',
#  'baruun-urt',
#  'song phi nong',
#  'catalina',
#  'amapa',
#  'santiago del estero',
#  'puerto del rosario',
#  'correntina',
#  'riyadh',
#  'roma',
#  'portland',
#  'saint anthony',
#  'palabuhanratu',
#  'sanski most',
#  'agno',
#  'hvolsvollur',
#  'san carlos de bariloche',
#  'warkworth',
#  'cayenne',
#  'avera',
#  'broken hill',
#  'port hawkesbury',
#  'kachikau',
#  'pevek',
#  'najran',
#  'macamic',
#  'flinders',
#  'tateyama',
#  'esso',
#  'sola',
#  'hofn',
#  'fomboni',
#  'tsumeb',
#  'okhotsk',
#  'xadani',
#  'dudinka',
#  'vao',
#  'harij',
#  'karaidel',
#  'manokwari',
#  'taldan',
#  'plettenberg bay',
#  'lasa',
#  'tokur',
#  'abay',
#  'tasbuget',
#  'paradwip',
#  'kazerun',
#  'arroio grande',
#  'dzhusaly',
#  'vikhorevka',
#  'njombe',
#  'hobyo',
#  'msanga',
#  'slave lake',
#  'gigmoto',
#  'felipe carrillo puerto',
#  'wewak',
#  'bemidji',
#  'chara',
#  'jian',
#  'arys',
#  'ardakan',
#  'husavik',
#  'constitucion',
#  'ambilobe',
#  'canberra',
#  'perth',
#  'nome',
#  'orlik',
#  'galle',
#  'kharp',
#  'kamenka',
#  'westport',
#  'turukhansk',
#  'arlit',
#  'karasburg',
#  'nador',
#  'pulandian',
#  'kez',
#  'dire',
#  'montabaur',
#  'iqaluit',
#  'hienghene',
#  'buala',
#  'kapit',
#  'denpasar',
#  'zabaykalsk',
#  'tuy hoa',
#  'curup',
#  'maragogi',
#  'jaru',
#  'kinsale',
#  'vostok',
#  'aktas',
#  'plakhtiyivka',
#  'kazalinsk',
#  'chon buri',
#  'sungaipenuh',
#  'tommot',
#  'gibsons',
#  'labuhan',
#  'montpelier',
#  'suba',
#  'weligama',
#  'kawalu',
#  'dourbali',
#  'antsohihy',
#  'mackenzie',
#  'poum',
#  'portales',
#  'mareeba',
#  'kilindoni',
#  'strezhevoy',
#  'jacareacanga',
#  'governador valadares',
#  'sibolga',
#  'hvammstangi',
#  'calatayud',
#  'vale da amoreira',
#  'biak',
#  'almeirim',
#  'suntar',
#  'dambovicioara',
#  'markova',
#  'san luis',
#  'kundiawa',
#  'dong hoi',
#  'calabozo',
#  'paraiso',
#  'sataua',
#  'robe',
#  'camocim',
#  'sabzevar',
#  'barra dos coqueiros',
#  'okato',
#  'bessonovka',
#  'hirara',
#  'kyzyl-suu',
#  'narsaq',
#  'xichang',
#  'vicksburg',
#  'port lincoln',
#  'velka bites',
#  'kinablangan',
#  'kogon',
#  'djenne',
#  'havre-saint-pierre',
#  'porto torres',
#  'yulara',
#  'dhidhdhoo',
#  'jacksonville',
#  'wagar',
#  'conde',
#  'dagana',
#  'yatou',
#  'aurdal',
#  'krasnoselkup',
#  'jiaonan',
#  'ondorhaan',
#  'imbituba',
#  'tepalcatepec',
#  'wamba',
#  'ust-kamchatsk',
#  'nha trang',
#  'north bend',
#  'nouakchott',
#  'lopandino',
#  'ust-maya',
#  'nkoteng',
#  'kalomo',
#  'yarada',
#  'jardim',
#  'scarborough',
#  'japura',
#  'saveh',
#  'novopokrovka',
#  'rawah']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Perform a weather check on each city using API Calls
# Build URL and query
url = "http://api.openweathermap.org/data/2.5/weather?"
# For temperature in Fahrenheit
city = ""
units = "imperial"


## Debugging with single city first
#city = cities[0]  
#city
#build_url = url+"appid="+api_key+"&q="+city+"&units="+units
##build_url
#json = requests.get(build_url).json()
## Get name value from json
#print(json['name'])

# Initial print
print(f"""Beginning Data Retrieval     
-----------------------------""")
# Initialize index to 1 and list to 1
city_idx = 1
set_idx = 1
# Initialize count to 0
recordcount = 1
# Initialize Data frame variables
City = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
MaxTemp = []
WindSpeed = []

#For loop for each city in the list
for city in cities:
    # For each city, get the weather data from JSON request and then print
    # Get weather data
    build_url = url+"appid="+api_key+"&q="+city+"&units="+units
    weather_response = requests.get(build_url)
    weather_json = requests.get(build_url).json()
    try:
        # Get Current City name value from the JSON data
        CurrentCity = weather_json['name']
        # Get all columns to be in data frame in List
        City.append(weather_json['name'])
        Cloudiness.append(weather_json['clouds']['all'])
        Country.append(weather_json['sys']['country'])
        Date.append(weather_json['dt'])
        Humidity.append(weather_json['main']['humidity'])
        Lat.append(weather_json['coord']['lat'])
        Lng.append(weather_json['coord']['lon'])
        MaxTemp.append(weather_json['main']['temp_max'])
        WindSpeed.append(weather_json['wind']['speed'])
        # Include a print log of each city as it's being processed (with the city number and city name).
        print(f"Processing Record {city_idx} of Set {set_idx} | {CurrentCity}")
    except KeyError:
        print(f"City not found. Skipping...")
    if(recordcount<50):
        city_idx += 1
        recordcount += 1
    else:
        set_idx += 1
        city_idx = 0
        recordcount = 1
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | Qinnan
# City not found. Skipping...
# Processing Record 3 of Set 1 | Mitu
# Processing Record 4 of Set 1 | Sao Joaquim
# Processing Record 5 of Set 1 | Port Blair
# Processing Record 6 of Set 1 | Mahebourg
# Processing Record 7 of Set 1 | Tessalit
# Processing Record 8 of Set 1 | Saint-Philippe
# Processing Record 9 of Set 1 | Grand Gaube
# Processing Record 10 of Set 1 | Warrensburg
# Processing Record 11 of Set 1 | Cabo San Lucas
# Processing Record 12 of Set 1 | Rikitea
# Processing Record 13 of Set 1 | Haines Junction
# Processing Record 14 of Set 1 | Pangkalanbuun
# City not found. Skipping...
# Processing Record 16 of Set 1 | Ostrovnoy
# Processing Record 17 of Set 1 | Torbay
# Processing Record 18 of Set 1 | Sitka
# City not found. Skipping...
# Processing Record 20 of Set 1 | Arauca
# Processing Record 21 of Set 1 | Puerto Ayora
# City not found. Skipping...
# Processing Record 23 of Set 1 | Chuy
# Processing Record 24 of Set 1 | Thompson
# City not found. Skipping...
# Processing Record 26 of Set 1 | Igboho
# Processing Record 27 of Set 1 | Hithadhoo
# Processing Record 28 of Set 1 | Atuona
# Processing Record 29 of Set 1 | Salalah
# Processing Record 30 of Set 1 | Albany
# Processing Record 31 of Set 1 | Tuktoyaktuk
# Processing Record 32 of Set 1 | Katsuura
# Processing Record 33 of Set 1 | Lavrentiya
# Processing Record 34 of Set 1 | Pangody
# City not found. Skipping...
# Processing Record 36 of Set 1 | Ivanjica
# Processing Record 37 of Set 1 | Hilo
# Processing Record 38 of Set 1 | Shingu
# City not found. Skipping...
# Processing Record 40 of Set 1 | Saldanha
# Processing Record 41 of Set 1 | Bethel
# Processing Record 42 of Set 1 | Klaksvik
# Processing Record 43 of Set 1 | Agua Verde
# Processing Record 44 of Set 1 | Quincy
# Processing Record 45 of Set 1 | Kalianget
# Processing Record 46 of Set 1 | Clyde River
# Processing Record 47 of Set 1 | Yellowknife
# Processing Record 48 of Set 1 | Dwarka
# Processing Record 49 of Set 1 | Talcahuano
# Processing Record 50 of Set 1 | Ayorou
# Processing Record 0 of Set 2 | Hobart
# Processing Record 1 of Set 2 | Chicama
# City not found. Skipping...
# Processing Record 3 of Set 2 | Krasnyy Chikoy
# Processing Record 4 of Set 2 | Eirunepe
# Processing Record 5 of Set 2 | Port Alfred
# Processing Record 6 of Set 2 | Pathein
# Processing Record 7 of Set 2 | Longyearbyen
# Processing Record 8 of Set 2 | Qaanaaq
# Processing Record 9 of Set 2 | Lerwick
# Processing Record 10 of Set 2 | Grindavik
# Processing Record 11 of Set 2 | Saint Lawrence
# Processing Record 12 of Set 2 | Vardo
# Processing Record 13 of Set 2 | Upernavik
# Processing Record 14 of Set 2 | Santa Fe
# Processing Record 15 of Set 2 | Waipawa
# Processing Record 16 of Set 2 | East London
# Processing Record 17 of Set 2 | Kapaa
# Processing Record 18 of Set 2 | New Norfolk
# City not found. Skipping...
# Processing Record 20 of Set 2 | Nome
# Processing Record 21 of Set 2 | Barrow
# Processing Record 22 of Set 2 | Marovoay
# Processing Record 23 of Set 2 | Mount Gambier
# Processing Record 24 of Set 2 | Selfoss
# Processing Record 25 of Set 2 | Georgetown
# Processing Record 26 of Set 2 | Mataura
# Processing Record 27 of Set 2 | Avarua
# Processing Record 28 of Set 2 | Hermanus
# Processing Record 29 of Set 2 | Nanakuli
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 2 | Punta Arenas
# Processing Record 33 of Set 2 | Coquimbo
# Processing Record 34 of Set 2 | Bogo
# Processing Record 35 of Set 2 | Castro
# City not found. Skipping...
# Processing Record 37 of Set 2 | Cape Town
# Processing Record 38 of Set 2 | Khatanga
# Processing Record 39 of Set 2 | Hambantota
# Processing Record 40 of Set 2 | Kodiak
# Processing Record 41 of Set 2 | Ixtapa
# Processing Record 42 of Set 2 | Yeppoon
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 2 | Fort Nelson
# Processing Record 46 of Set 2 | Dikson
# Processing Record 47 of Set 2 | Bluff
# Processing Record 48 of Set 2 | Kavaratti
# Processing Record 49 of Set 2 | Imeni Zhelyabova
# Processing Record 0 of Set 3 | Muros
# Processing Record 1 of Set 3 | Busselton
# Processing Record 2 of Set 3 | Tarko-Sale
# City not found. Skipping...
# Processing Record 4 of Set 3 | Pevek
# Processing Record 5 of Set 3 | Bilma
# Processing Record 6 of Set 3 | Kaitangata
# City not found. Skipping...
# Processing Record 8 of Set 3 | Port Keats
# Processing Record 9 of Set 3 | Qaqortoq
# Processing Record 10 of Set 3 | Aracataca
# City not found. Skipping...
# Processing Record 12 of Set 3 | Beibei
# City not found. Skipping...
# Processing Record 14 of Set 3 | Hoi An
# Processing Record 15 of Set 3 | Gold Coast
# City not found. Skipping...
# Processing Record 17 of Set 3 | Bela pod Bezdezem
# Processing Record 18 of Set 3 | Axim
# Processing Record 19 of Set 3 | Bredasdorp
# Processing Record 20 of Set 3 | Belaya Gora
# Processing Record 21 of Set 3 | Ushuaia
# Processing Record 22 of Set 3 | Srednekolymsk
# Processing Record 23 of Set 3 | Norman Wells
# City not found. Skipping...
# Processing Record 25 of Set 3 | Bonavista
# Processing Record 26 of Set 3 | Bida
# Processing Record 27 of Set 3 | La Paz
# Processing Record 28 of Set 3 | Kalyazin
# Processing Record 29 of Set 3 | Airai
# Processing Record 30 of Set 3 | Bandarbeyla
# Processing Record 31 of Set 3 | Manado
# Processing Record 32 of Set 3 | Marshall
# Processing Record 33 of Set 3 | Polunochnoye
# Processing Record 34 of Set 3 | Copiapo
# Processing Record 35 of Set 3 | Vaini
# Processing Record 36 of Set 3 | Caravelas
# Processing Record 37 of Set 3 | Santa Rosa del Sur
# City not found. Skipping...
# Processing Record 39 of Set 3 | Mao
# Processing Record 40 of Set 3 | Saint George
# Processing Record 41 of Set 3 | Esperance
# City not found. Skipping...
# Processing Record 43 of Set 3 | Waingapu
# City not found. Skipping...
# Processing Record 45 of Set 3 | Hasaki
# Processing Record 46 of Set 3 | Namatanai
# Processing Record 47 of Set 3 | Mar del Plata
# Processing Record 48 of Set 3 | Bondo
# Processing Record 49 of Set 3 | Iqaluit
# Processing Record 0 of Set 4 | Saint-Joseph
# Processing Record 1 of Set 4 | Fairbanks
# Processing Record 2 of Set 4 | Corner Brook
# Processing Record 3 of Set 4 | Faanui
# Processing Record 4 of Set 4 | Balesti
# Processing Record 5 of Set 4 | Mexico
# Processing Record 6 of Set 4 | Novikovo
# Processing Record 7 of Set 4 | Tasiilaq
# Processing Record 8 of Set 4 | Petropavlovsk-Kamchatskiy
# Processing Record 9 of Set 4 | Chinhoyi
# Processing Record 10 of Set 4 | Yuxia
# Processing Record 11 of Set 4 | Toppenish
# Processing Record 12 of Set 4 | Zachary
# Processing Record 13 of Set 4 | Ancud
# Processing Record 14 of Set 4 | Butaritari
# Processing Record 15 of Set 4 | Araouane
# City not found. Skipping...
# Processing Record 17 of Set 4 | Northam
# Processing Record 18 of Set 4 | Soyo
# Processing Record 19 of Set 4 | Nikolskoye
# Processing Record 20 of Set 4 | Codrington
# Processing Record 21 of Set 4 | Kuminskiy
# Processing Record 22 of Set 4 | Pyshchug
# Processing Record 23 of Set 4 | Moranbah
# Processing Record 24 of Set 4 | Lebu
# Processing Record 25 of Set 4 | Matucana
# Processing Record 26 of Set 4 | Cidreira
# Processing Record 27 of Set 4 | Srandakan
# Processing Record 28 of Set 4 | Vestmanna
# Processing Record 29 of Set 4 | Conway
# Processing Record 30 of Set 4 | Kavieng
# City not found. Skipping...
# Processing Record 32 of Set 4 | Avera
# Processing Record 33 of Set 4 | Mercedes
# Processing Record 34 of Set 4 | Loei
# Processing Record 35 of Set 4 | Vikulovo
# Processing Record 36 of Set 4 | Thinadhoo
# Processing Record 37 of Set 4 | Carnarvon
# Processing Record 38 of Set 4 | Indiaroba
# Processing Record 39 of Set 4 | La Primavera
# Processing Record 40 of Set 4 | Egvekinot
# Processing Record 41 of Set 4 | Oktyabrskiy
# Processing Record 42 of Set 4 | Daryapur
# Processing Record 43 of Set 4 | Lompoc
# Processing Record 44 of Set 4 | Rumonge
# Processing Record 45 of Set 4 | Coihaique
# City not found. Skipping...
# Processing Record 47 of Set 4 | Guerrero Negro
# Processing Record 48 of Set 4 | Finote Selam
# Processing Record 49 of Set 4 | Xuanzhou
# Processing Record 0 of Set 5 | Tiksi
# Processing Record 1 of Set 5 | Apollonia
# Processing Record 2 of Set 5 | Puerto Escondido
# Processing Record 3 of Set 5 | Sao Felix do Xingu
# Processing Record 4 of Set 5 | Anadyr
# Processing Record 5 of Set 5 | Laguna
# City not found. Skipping...
# Processing Record 7 of Set 5 | Victoria
# Processing Record 8 of Set 5 | Katangli
# Processing Record 9 of Set 5 | Caala
# Processing Record 10 of Set 5 | Mahibadhoo
# Processing Record 11 of Set 5 | Jamestown
# Processing Record 12 of Set 5 | Zeya
# Processing Record 13 of Set 5 | Cherskiy
# Processing Record 14 of Set 5 | Ponta do Sol
# Processing Record 15 of Set 5 | Aklavik
# Processing Record 16 of Set 5 | Nefteyugansk
# Processing Record 17 of Set 5 | Warri
# Processing Record 18 of Set 5 | Makakilo City
# Processing Record 19 of Set 5 | Jadu
# Processing Record 20 of Set 5 | Inhambane
# Processing Record 21 of Set 5 | Toora-Khem
# Processing Record 22 of Set 5 | Poronaysk
# Processing Record 23 of Set 5 | Hami
# Processing Record 24 of Set 5 | Portel
# Processing Record 25 of Set 5 | Karlskoga
# Processing Record 26 of Set 5 | Pochutla
# Processing Record 27 of Set 5 | Hovd
# Processing Record 28 of Set 5 | Broome
# Processing Record 29 of Set 5 | Tuatapere
# Processing Record 30 of Set 5 | Manta
# Processing Record 31 of Set 5 | Saint-Augustin
# Processing Record 32 of Set 5 | Burnie
# Processing Record 33 of Set 5 | Pacifica
# Processing Record 34 of Set 5 | Vestmannaeyjar
# Processing Record 35 of Set 5 | Vero Beach
# Processing Record 36 of Set 5 | Chistogorskiy
# City not found. Skipping...
# Processing Record 38 of Set 5 | Paragominas
# Processing Record 39 of Set 5 | Artyom
# Processing Record 40 of Set 5 | Dingle
# Processing Record 41 of Set 5 | Sibolga
# Processing Record 42 of Set 5 | Ajdabiya
# Processing Record 43 of Set 5 | Alta Floresta
# Processing Record 44 of Set 5 | Saskylakh
# Processing Record 45 of Set 5 | Qinhuangdao
# Processing Record 46 of Set 5 | Ribeira Grande
# Processing Record 47 of Set 5 | Bykovo
# Processing Record 48 of Set 5 | Ca Mau
# Processing Record 49 of Set 5 | Tilichiki
# Processing Record 0 of Set 6 | Agadez
# Processing Record 1 of Set 6 | Henties Bay
# City not found. Skipping...
# Processing Record 3 of Set 6 | Severo-Kurilsk
# Processing Record 4 of Set 6 | Sayhat
# Processing Record 5 of Set 6 | Acajutla
# Processing Record 6 of Set 6 | Yulara
# Processing Record 7 of Set 6 | Sao Jose da Coroa Grande
# Processing Record 8 of Set 6 | Lufilufi
# Processing Record 9 of Set 6 | Souillac
# Processing Record 10 of Set 6 | Panguna
# Processing Record 11 of Set 6 | The Valley
# Processing Record 12 of Set 6 | Fare
# Processing Record 13 of Set 6 | Behbahan
# City not found. Skipping...
# Processing Record 15 of Set 6 | Khani
# Processing Record 16 of Set 6 | Niksar
# Processing Record 17 of Set 6 | Kropotkin
# Processing Record 18 of Set 6 | Mosquera
# Processing Record 19 of Set 6 | Cayenne
# Processing Record 20 of Set 6 | Sao Joao da Barra
# Processing Record 21 of Set 6 | Sokoto
# Processing Record 22 of Set 6 | Bay Roberts
# Processing Record 23 of Set 6 | Bol
# Processing Record 24 of Set 6 | Siocon
# Processing Record 25 of Set 6 | Port Elizabeth
# Processing Record 26 of Set 6 | Beyneu
# Processing Record 27 of Set 6 | Rajpipla
# Processing Record 28 of Set 6 | Camopi
# Processing Record 29 of Set 6 | Pustoshka
# City not found. Skipping...
# Processing Record 31 of Set 6 | Djambala
# Processing Record 32 of Set 6 | Teya
# Processing Record 33 of Set 6 | Trinidad
# City not found. Skipping...
# Processing Record 35 of Set 6 | Krasnovishersk
# Processing Record 36 of Set 6 | Ponnani
# Processing Record 37 of Set 6 | Buala
# Processing Record 38 of Set 6 | Joshimath
# Processing Record 39 of Set 6 | Sandanski
# Processing Record 40 of Set 6 | High Level
# Processing Record 41 of Set 6 | Kamaishi
# Processing Record 42 of Set 6 | Cabra
# Processing Record 43 of Set 6 | Brae
# Processing Record 44 of Set 6 | Udachnyy
# Processing Record 45 of Set 6 | La Ronge
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of Set 6 | Mago
# Processing Record 49 of Set 6 | Kungurtug
# Processing Record 0 of Set 7 | Kurilsk
# City not found. Skipping...
# Processing Record 2 of Set 7 | Sile
# Processing Record 3 of Set 7 | Caxias
# Processing Record 4 of Set 7 | Bodden Town
# Processing Record 5 of Set 7 | Smithers
# Processing Record 6 of Set 7 | Yokadouma
# Processing Record 7 of Set 7 | Vao
# Processing Record 8 of Set 7 | Cockburn Town
# Processing Record 9 of Set 7 | Olga
# Processing Record 10 of Set 7 | Doha
# Processing Record 11 of Set 7 | Garowe
# Processing Record 12 of Set 7 | Oriximina
# City not found. Skipping...
# Processing Record 14 of Set 7 | Chokurdakh
# Processing Record 15 of Set 7 | Atasu
# Processing Record 16 of Set 7 | Baherden
# Processing Record 17 of Set 7 | Burns Lake
# Processing Record 18 of Set 7 | Karasjok
# Processing Record 19 of Set 7 | Gazanjyk
# City not found. Skipping...
# Processing Record 21 of Set 7 | Uelzen
# Processing Record 22 of Set 7 | Okhotsk
# Processing Record 23 of Set 7 | Alofi
# Processing Record 24 of Set 7 | Tura
# Processing Record 25 of Set 7 | Quatre Cocos
# Processing Record 26 of Set 7 | Lucea
# Processing Record 27 of Set 7 | Kunashak
# Processing Record 28 of Set 7 | Sembakung
# Processing Record 29 of Set 7 | Labuhan
# City not found. Skipping...
# Processing Record 31 of Set 7 | Tiznit
# Processing Record 32 of Set 7 | Ilulissat
# Processing Record 33 of Set 7 | Provideniya
# Processing Record 34 of Set 7 | Talnakh
# Processing Record 35 of Set 7 | Yashkul
# Processing Record 36 of Set 7 | Evansville
# Processing Record 37 of Set 7 | Mwinilunga
# Processing Record 38 of Set 7 | Sao Filipe
# Processing Record 39 of Set 7 | General Roca
# Processing Record 40 of Set 7 | Ulladulla
# Processing Record 41 of Set 7 | Lukovetskiy
# Processing Record 42 of Set 7 | Kahului
# Processing Record 43 of Set 7 | Camrose
# Processing Record 44 of Set 7 | Kindu
# Processing Record 45 of Set 7 | Comodoro Rivadavia
# Processing Record 46 of Set 7 | Bela
# Processing Record 47 of Set 7 | Bam
# Processing Record 48 of Set 7 | Rock Sound
# Processing Record 49 of Set 7 | Scarborough
# Processing Record 0 of Set 8 | Semey
# Processing Record 1 of Set 8 | Vila do Maio
# Processing Record 2 of Set 8 | Leshukonskoye
# Processing Record 3 of Set 8 | Woodward
# Processing Record 4 of Set 8 | Tazovskiy
# Processing Record 5 of Set 8 | Trelew
# City not found. Skipping...
# Processing Record 7 of Set 8 | Bambous Virieux
# Processing Record 8 of Set 8 | Abu Dhabi
# Processing Record 9 of Set 8 | Richards Bay
# Processing Record 10 of Set 8 | San Cristobal
# Processing Record 11 of Set 8 | Tahe
# Processing Record 12 of Set 8 | Florissant
# Processing Record 13 of Set 8 | Havelock
# Processing Record 14 of Set 8 | Peniche
# Processing Record 15 of Set 8 | Puqi
# Processing Record 16 of Set 8 | Kangaatsiaq
# Processing Record 17 of Set 8 | Bandrele
# Processing Record 18 of Set 8 | Hay River
# Processing Record 19 of Set 8 | Peterhead
# Processing Record 20 of Set 8 | Viedma
# Processing Record 21 of Set 8 | Leningradskiy
# Processing Record 22 of Set 8 | Constitucion
# Processing Record 23 of Set 8 | Vitim
# Processing Record 24 of Set 8 | Mandera
# City not found. Skipping...
# Processing Record 26 of Set 8 | Novorzhev
# Processing Record 27 of Set 8 | Campbell River
# Processing Record 28 of Set 8 | Abu Samrah
# Processing Record 29 of Set 8 | Rorvik
# Processing Record 30 of Set 8 | Burhaniye
# Processing Record 31 of Set 8 | Arraial do Cabo
# Processing Record 32 of Set 8 | Sur
# Processing Record 33 of Set 8 | Paamiut
# Processing Record 34 of Set 8 | Geraldton
# Processing Record 35 of Set 8 | Sorland
# Processing Record 36 of Set 8 | Palana
# Processing Record 37 of Set 8 | Kruisfontein
# Processing Record 38 of Set 8 | Jaboatao
# Processing Record 39 of Set 8 | Hobyo
# Processing Record 40 of Set 8 | Nantucket
# Processing Record 41 of Set 8 | Bocas del Toro
# Processing Record 42 of Set 8 | Broken Hill
# City not found. Skipping...
# Processing Record 44 of Set 8 | Bathsheba
# Processing Record 45 of Set 8 | Macau
# Processing Record 46 of Set 8 | Idlib
# Processing Record 47 of Set 8 | Machilipatnam
# City not found. Skipping...
# Processing Record 49 of Set 8 | Rome
# Processing Record 0 of Set 9 | Suntar
# Processing Record 1 of Set 9 | Matiguas
# Processing Record 2 of Set 9 | Sosnovka
# Processing Record 3 of Set 9 | Saint-Pierre
# Processing Record 4 of Set 9 | College
# City not found. Skipping...
# Processing Record 6 of Set 9 | Gorin
# Processing Record 7 of Set 9 | San Patricio
# Processing Record 8 of Set 9 | Sainte-Maxime
# Processing Record 9 of Set 9 | Shimanovsk
# Processing Record 10 of Set 9 | Sobolevo
# Processing Record 11 of Set 9 | Quang Ngai
# City not found. Skipping...
# Processing Record 13 of Set 9 | Port Hardy
# Processing Record 14 of Set 9 | Chernyshevskiy
# Processing Record 15 of Set 9 | Sabang
# Processing Record 16 of Set 9 | Sioux Lookout
# Processing Record 17 of Set 9 | Mogocha
# Processing Record 18 of Set 9 | Lorengau
# Processing Record 19 of Set 9 | Opuwo
# City not found. Skipping...
# Processing Record 21 of Set 9 | Marawi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 9 | Ushtobe
# Processing Record 25 of Set 9 | Carauari
# Processing Record 26 of Set 9 | Mattawa
# Processing Record 27 of Set 9 | Ko Samui
# Processing Record 28 of Set 9 | Beringovskiy
# Processing Record 29 of Set 9 | Najran
# Processing Record 30 of Set 9 | Shimoda
# Processing Record 31 of Set 9 | Dalen
# Processing Record 32 of Set 9 | Teguise
# City not found. Skipping...
# Processing Record 34 of Set 9 | Boguchany
# Processing Record 35 of Set 9 | Borogontsy
# Processing Record 36 of Set 9 | Dolores
# Processing Record 37 of Set 9 | Sambava
# Processing Record 38 of Set 9 | Shenjiamen
# Processing Record 39 of Set 9 | Kortkeros
# Processing Record 40 of Set 9 | Maceio
# City not found. Skipping...
# Processing Record 42 of Set 9 | Severo-Yeniseyskiy
# City not found. Skipping...
# Processing Record 44 of Set 9 | Las Vegas
# Processing Record 45 of Set 9 | Athens
# Processing Record 46 of Set 9 | Rosarito
# Processing Record 47 of Set 9 | Tougan
# City not found. Skipping...
# Processing Record 49 of Set 9 | Ahipara
# Processing Record 0 of Set 10 | Lasa
# Processing Record 1 of Set 10 | Koutsouras
# Processing Record 2 of Set 10 | Valdivia
# Processing Record 3 of Set 10 | Cururupu
# City not found. Skipping...
# Processing Record 5 of Set 10 | Kostomuksha
# Processing Record 6 of Set 10 | Portland
# Processing Record 7 of Set 10 | Santa Rosalia
# Processing Record 8 of Set 10 | Puerto Madryn
# Processing Record 9 of Set 10 | Gornyy
# Processing Record 10 of Set 10 | Adrar
# Processing Record 11 of Set 10 | Dunedin
# Processing Record 12 of Set 10 | Luau
# Processing Record 13 of Set 10 | Mana
# Processing Record 14 of Set 10 | Eucaliptus
# Processing Record 15 of Set 10 | Peace River
# Processing Record 16 of Set 10 | Zhigansk
# Processing Record 17 of Set 10 | Oskarshamn
# Processing Record 18 of Set 10 | Waddan
# Processing Record 19 of Set 10 | Kelvington
# Processing Record 20 of Set 10 | Rosamorada
# Processing Record 21 of Set 10 | Sechura
# Processing Record 22 of Set 10 | Pisco
# Processing Record 23 of Set 10 | Cape Girardeau
# Processing Record 24 of Set 10 | Baykit
# Processing Record 25 of Set 10 | Touros
# Processing Record 26 of Set 10 | Beloha
# Processing Record 27 of Set 10 | Kudahuvadhoo
# Processing Record 28 of Set 10 | Kang
# Processing Record 29 of Set 10 | Kiunga
# Processing Record 30 of Set 10 | Dukat
# Processing Record 31 of Set 10 | Rumphi
# Processing Record 32 of Set 10 | Sao Geraldo do Araguaia
# Processing Record 33 of Set 10 | Neiafu
# Processing Record 34 of Set 10 | Gheorgheni
# Processing Record 35 of Set 10 | Riviere-au-Renard
# Processing Record 36 of Set 10 | Husavik
# Processing Record 37 of Set 10 | Visp
# City not found. Skipping...
# Processing Record 39 of Set 10 | Oranjemund
# Processing Record 40 of Set 10 | Volga
# Processing Record 41 of Set 10 | Narsaq
# Processing Record 42 of Set 10 | Puerto Ayacucho
# City not found. Skipping...
# Processing Record 44 of Set 10 | Voyvozh
# Processing Record 45 of Set 10 | Buncrana
# Processing Record 46 of Set 10 | Vereshchagino
# Processing Record 47 of Set 10 | Kitui
# Processing Record 48 of Set 10 | Strezhevoy
# Processing Record 49 of Set 10 | Tupik
# Processing Record 0 of Set 11 | Guanica
# Processing Record 1 of Set 11 | Nemuro
# Processing Record 2 of Set 11 | Mackenzie
# Processing Record 3 of Set 11 | Oranjestad
# Processing Record 4 of Set 11 | Meadow Lake
# Processing Record 5 of Set 11 | Maningrida
# Processing Record 6 of Set 11 | Meulaboh
# Processing Record 7 of Set 11 | Nuuk
# City not found. Skipping...
# Processing Record 9 of Set 11 | Finnsnes
# Processing Record 10 of Set 11 | Tigzirt
# Processing Record 11 of Set 11 | Roald
# Processing Record 12 of Set 11 | Imbituba
# Processing Record 13 of Set 11 | Ulagan
# City not found. Skipping...
# Processing Record 15 of Set 11 | Taltal
# Processing Record 16 of Set 11 | Port Macquarie
# Processing Record 17 of Set 11 | Wuda
# Processing Record 18 of Set 11 | Belgrade
# Processing Record 19 of Set 11 | Ipixuna
# Processing Record 20 of Set 11 | Moshi
# Processing Record 21 of Set 11 | Lewistown
# Processing Record 22 of Set 11 | Pitimbu
# City not found. Skipping...
# Processing Record 24 of Set 11 | Gilgit
# Processing Record 25 of Set 11 | Morgan City
# Processing Record 26 of Set 11 | Borzya
# Processing Record 27 of Set 11 | Fukue
# Processing Record 28 of Set 11 | Canutama
# Processing Record 29 of Set 11 | Evans
# Processing Record 30 of Set 11 | Berlevag
# City not found. Skipping...
# Processing Record 32 of Set 11 | Polohy
# Processing Record 33 of Set 11 | Elko
# Processing Record 34 of Set 11 | Isangel
# Processing Record 35 of Set 11 | Nuevo Progreso
# Processing Record 36 of Set 11 | Ailigandi
# Processing Record 37 of Set 11 | Walvis Bay
# Processing Record 38 of Set 11 | Mareeba
# Processing Record 39 of Set 11 | Barcelos
# Processing Record 40 of Set 11 | Florida
# City not found. Skipping...
# Processing Record 42 of Set 11 | Port Hedland
# Processing Record 43 of Set 11 | Ust-Nera
# Processing Record 44 of Set 11 | Samarai
# Processing Record 45 of Set 11 | Acari
# Processing Record 46 of Set 11 | Magadan
# Processing Record 47 of Set 11 | Loa Janan
# Processing Record 48 of Set 11 | Libourne
# Processing Record 49 of Set 11 | Parabel
# Processing Record 0 of Set 12 | Luanda
# Processing Record 1 of Set 12 | Chipinge
# City not found. Skipping...
# Processing Record 3 of Set 12 | Bansko
# Processing Record 4 of Set 12 | Along
# Processing Record 5 of Set 12 | Bongor
# Processing Record 6 of Set 12 | Mbanza-Ngungu
# Processing Record 7 of Set 12 | Dubna
# City not found. Skipping...
# Processing Record 9 of Set 12 | Teguldet
# Processing Record 10 of Set 12 | Rudnya
# Processing Record 11 of Set 12 | Matadi
# Processing Record 12 of Set 12 | Palmer
# Processing Record 13 of Set 12 | Taoudenni
# Processing Record 14 of Set 12 | Usakos
# Processing Record 15 of Set 12 | Gao
# Processing Record 16 of Set 12 | LOS ALGARROBOS
# Processing Record 17 of Set 12 | Shintomi
# Processing Record 18 of Set 12 | Noumea
# Processing Record 19 of Set 12 | Bubaque
# Processing Record 20 of Set 12 | Blagoyevo
# Processing Record 21 of Set 12 | Nikolayevsk-na-amure
# Processing Record 22 of Set 12 | Maraba
# Processing Record 23 of Set 12 | Quthing
# Processing Record 24 of Set 12 | Port-Gentil
# Processing Record 25 of Set 12 | Los Chiles
# Processing Record 26 of Set 12 | Morro Bay
# City not found. Skipping...
# Processing Record 28 of Set 12 | Tabuk
# Processing Record 29 of Set 12 | Mehamn
# Processing Record 30 of Set 12 | Praia da Vitoria
# Processing Record 31 of Set 12 | Dumas
# Processing Record 32 of Set 12 | Otradnoye
# Processing Record 33 of Set 12 | Oussouye
# Processing Record 34 of Set 12 | Ivybridge
# Processing Record 35 of Set 12 | Birnin Kebbi
# Processing Record 36 of Set 12 | Lagoa
# Processing Record 37 of Set 12 | Lodwar
# City not found. Skipping...
# Processing Record 39 of Set 12 | Chegdomyn
# City not found. Skipping...
# Processing Record 41 of Set 12 | Mackay
# Processing Record 42 of Set 12 | Chancay
# Processing Record 43 of Set 12 | Kasempa
# Processing Record 44 of Set 12 | Benton Harbor
# Processing Record 45 of Set 12 | Rochegda
# Processing Record 46 of Set 12 | Mecca
# Processing Record 47 of Set 12 | Sehithwa
# Processing Record 48 of Set 12 | Catanzaro
# Processing Record 49 of Set 12 | Amapa
# Processing Record 0 of Set 13 | Kati
# Processing Record 1 of Set 13 | Xai-Xai
# Processing Record 2 of Set 13 | Bilibino

# %% [markdown]
# ## Convert Raw Data to DataFrame
# * Export the city data into a .csv.
#
# * Display the DataFrame

# %%
### Convert Raw Data to DataFrame

# Debug
#weather_json['name']
#weather_json['wind']['speed']
#weather_json['speed']
#weather_json
#summary = ["name","country","dt"]
#weather_json2 = [response(*summary) for response in weather_json]

# Extract required columns from JSON data
# Create a Pandas DataFrame with the results
weather_data = pd.DataFrame(
{
 'City':City,
 'Cloudiness':Cloudiness,
 'Country':Country,
 'Date':Date,
 'Humidity':Humidity,
 'Lat':Lat,
 'Lng':Lng,
 'Max Temp':MaxTemp,
 'Wind Speed':WindSpeed
})

# Export the city data into a .csv.
# Need OS module to create new directory,and need encoding to convert to csv file
if("output_data"==False):
    os.mkdir('output_data')
weather_data.to_csv(output_data_file, encoding='utf-8', index=False)

# Display the DataFrame
weather_data.count()
#weather_json
# Out:
# City          539
# Cloudiness    539
# Country       539
# Date          539
# Humidity      539
# Lat           539
# Lng           539
# Max Temp      539
# Wind Speed    539
# dtype: int64

# %%
weather_data.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Qinnan           0      CN  1540431215        62  33.25  119.91
# 1         Mitu          48      IR  1540431215        60  36.20   46.09
# 2  Sao Joaquim          48      BR  1540431215        98 -28.29  -49.93
# 3   Port Blair          92      IN  1540431216       100  11.67   92.75
# 4    Mahebourg          40      MU  1540429200        77 -20.41   57.70
#
#    Max Temp  Wind Speed
# 0     70.93       13.27
# 1     54.77        8.01
# 2     51.26        4.21
# 3     82.45        3.42
# 4     69.80        4.70

# %%
# Cell to get current date to be used in graphs below
import datetime

now = datetime.datetime.now()
CurrentDate = now.strftime("%Y-%m-%d")
print(CurrentDate)
# Out:
# 2018-10-24

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Plot Lat and Max Temp
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

# Plot limits
plt.xlim(min(Lat)-5,max(Lat)+5)
plt.ylim(min(MaxTemp)-10,max(MaxTemp)+10)

plt.grid()
plt.tight_layout()
plt.title(f"City Latitude vs Max Temperature ({CurrentDate})")
plt.scatter(Lat,MaxTemp,marker="o",facecolors="steelblue",alpha=0.75,edgecolors='black')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Plot Lat and Humidity
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Plot limits
plt.xlim(min(Lat)-5,max(Lat)+5)
plt.ylim(min(Humidity)-5,max(Humidity)+5)

plt.grid()
plt.tight_layout()
plt.title(f"City Latitude vs Humidity ({CurrentDate})")
plt.scatter(Lat,Humidity,marker="o",facecolors="steelblue",alpha=0.75,edgecolors='black')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Plot Lat and Humidity
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Plot limits
plt.xlim(min(Lat)-5,max(Lat)+5)
plt.ylim(min(Cloudiness)-5,max(Cloudiness)+5)

plt.grid()
plt.tight_layout()
plt.title(f"City Latitude vs Cloudiness ({CurrentDate})")
plt.scatter(Lat,Cloudiness,marker="o",facecolors="steelblue",alpha=0.75,edgecolors='black')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Plot Lat and Humidity
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Plot limits
plt.xlim(min(Lat)-5,max(Lat)+5)
plt.ylim(min(WindSpeed)-5,max(WindSpeed)+5)

plt.grid()
plt.tight_layout()
plt.title(f"City Latitude vs Wind Speed ({CurrentDate})")
plt.scatter(Lat,WindSpeed,marker="o",facecolors="steelblue",alpha=0.75,edgecolors='black')
